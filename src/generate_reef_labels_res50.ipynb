# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
from loader import DataLoader
dl = DataLoader()
train_primitive_matrix, val_primitive_matrix, test_primitive_matrix, \
train_ground, val_ground, test_ground, mode, frameNums = dl.load_data(mode = 'res50', numFramesToLoad = 1000)
# mode stores the method of loading data here
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 1 frames successfully loaded out of 1000
# 2 frames successfully loaded out of 1000
# 3 frames successfully loaded out of 1000
# 4 frames successfully loaded out of 1000
# 5 frames successfully loaded out of 1000
# 6 frames successfully loaded out of 1000
# 7 frames successfully loaded out of 1000
# 8 frames successfully loaded out of 1000
# 9 frames successfully loaded out of 1000
# 10 frames successfully loaded out of 1000
# 11 frames successfully loaded out of 1000
# 12 frames successfully loaded out of 1000
# 13 frames successfully loaded out of 1000
# 14 frames successfully loaded out of 1000
# 15 frames successfully loaded out of 1000
# 16 frames successfully loaded out of 1000
# 17 frames successfully loaded out of 1000
# 18 frames successfully loaded out of 1000
# 19 frames successfully loaded out of 1000
# 20 frames successfully loaded out of 1000
# 21 frames successfully loaded out of 1000
# 22 frames successfully loaded out of 1000
# 23 frames successfully loaded out of 1000
# 24 frames successfully loaded out of 1000
# 25 frames successfully loaded out of 1000
# 26 frames successfully loaded out of 1000
# 27 frames successfully loaded out of 1000
# 28 frames successfully loaded out of 1000
# 29 frames successfully loaded out of 1000
# 30 frames successfully loaded out of 1000
# 31 frames successfully loaded out of 1000
# 32 frames successfully loaded out of 1000
# 33 frames successfully loaded out of 1000
# 34 frames successfully loaded out of 1000
# 35 frames successfully loaded out of 1000
# 36 frames successfully loaded out of 1000
# 37 frames successfully loaded out of 1000
# 38 frames successfully loaded out of 1000
# 39 frames successfully loaded out of 1000
# 40 frames successfully loaded out of 1000
# 41 frames successfully loaded out of 1000
# 42 frames successfully loaded out of 1000
# 43 frames successfully loaded out of 1000
# 44 frames successfully loaded out of 1000
# 45 frames successfully loaded out of 1000
# 46 frames successfully loaded out of 1000
# 47 frames successfully loaded out of 1000
# 48 frames successfully loaded out of 1000
# 49 frames successfully loaded out of 1000
# 50 frames successfully loaded out of 1000
# 51 frames successfully loaded out of 1000
# 52 frames successfully loaded out of 1000
# 53 frames successfully loaded out of 1000
# 54 frames successfully loaded out of 1000
# 55 frames successfully loaded out of 1000
# 56 frames successfully loaded out of 1000
# 57 frames successfully loaded out of 1000
# 58 frames successfully loaded out of 1000
# 59 frames successfully loaded out of 1000
# 60 frames successfully loaded out of 1000
# 61 frames successfully loaded out of 1000
# 62 frames successfully loaded out of 1000
# 63 frames successfully loaded out of 1000
# 64 frames successfully loaded out of 1000
# 65 frames successfully loaded out of 1000
# 66 frames successfully loaded out of 1000
# 67 frames successfully loaded out of 1000
# 68 frames successfully loaded out of 1000
# 69 frames successfully loaded out of 1000
# 70 frames successfully loaded out of 1000
# 71 frames successfully loaded out of 1000
# 72 frames successfully loaded out of 1000
# 73 frames successfully loaded out of 1000
# 74 frames successfully loaded out of 1000
# 75 frames successfully loaded out of 1000
# 76 frames successfully loaded out of 1000
# 77 frames successfully loaded out of 1000
# 78 frames successfully loaded out of 1000
# 79 frames successfully loaded out of 1000
# 80 frames successfully loaded out of 1000
# 81 frames successfully loaded out of 1000
# 82 frames successfully loaded out of 1000
# 83 frames successfully loaded out of 1000
# 84 frames successfully loaded out of 1000
# 85 frames successfully loaded out of 1000
# 86 frames successfully loaded out of 1000
# 87 frames successfully loaded out of 1000
# 88 frames successfully loaded out of 1000
# 89 frames successfully loaded out of 1000
# 90 frames successfully loaded out of 1000
# 91 frames successfully loaded out of 1000
# 92 frames successfully loaded out of 1000
# 93 frames successfully loaded out of 1000
# 94 frames successfully loaded out of 1000
# 95 frames successfully loaded out of 1000
# 96 frames successfully loaded out of 1000
# 97 frames successfully loaded out of 1000
# 98 frames successfully loaded out of 1000
# 99 frames successfully loaded out of 1000
# 100 frames successfully loaded out of 1000
# 101 frames successfully loaded out of 1000
# 102 frames successfully loaded out of 1000
# 103 frames successfully loaded out of 1000
# 104 frames successfully loaded out of 1000
# 105 frames successfully loaded out of 1000
# 106 frames successfully loaded out of 1000
# 107 frames successfully loaded out of 1000
# 108 frames successfully loaded out of 1000
# 109 frames successfully loaded out of 1000
# 110 frames successfully loaded out of 1000
# 111 frames successfully loaded out of 1000
# 112 frames successfully loaded out of 1000
# 113 frames successfully loaded out of 1000
# 114 frames successfully loaded out of 1000
# 115 frames successfully loaded out of 1000
# 116 frames successfully loaded out of 1000
# 117 frames successfully loaded out of 1000
# 118 frames successfully loaded out of 1000
# 119 frames successfully loaded out of 1000
# 120 frames successfully loaded out of 1000
# 121 frames successfully loaded out of 1000
# 122 frames successfully loaded out of 1000
# 123 frames successfully loaded out of 1000
# 124 frames successfully loaded out of 1000
# 125 frames successfully loaded out of 1000
# 126 frames successfully loaded out of 1000
# 127 frames successfully loaded out of 1000
# 128 frames successfully loaded out of 1000
# 129 frames successfully loaded out of 1000
# 130 frames successfully loaded out of 1000
# 131 frames successfully loaded out of 1000
# 132 frames successfully loaded out of 1000
# 133 frames successfully loaded out of 1000
# 134 frames successfully loaded out of 1000
# 135 frames successfully loaded out of 1000
# 136 frames successfully loaded out of 1000
# 137 frames successfully loaded out of 1000
# 138 frames successfully loaded out of 1000
# 139 frames successfully loaded out of 1000
# 140 frames successfully loaded out of 1000
# 141 frames successfully loaded out of 1000
# 142 frames successfully loaded out of 1000
# 143 frames successfully loaded out of 1000
# 144 frames successfully loaded out of 1000
# 145 frames successfully loaded out of 1000
# 146 frames successfully loaded out of 1000
# 147 frames successfully loaded out of 1000
# 148 frames successfully loaded out of 1000
# 149 frames successfully loaded out of 1000
# 150 frames successfully loaded out of 1000
# 151 frames successfully loaded out of 1000
# 152 frames successfully loaded out of 1000
# 153 frames successfully loaded out of 1000
# 154 frames successfully loaded out of 1000
# 155 frames successfully loaded out of 1000
# 156 frames successfully loaded out of 1000
# 157 frames successfully loaded out of 1000
# 158 frames successfully loaded out of 1000
# 159 frames successfully loaded out of 1000
# 160 frames successfully loaded out of 1000
# 161 frames successfully loaded out of 1000
# 162 frames successfully loaded out of 1000
# 163 frames successfully loaded out of 1000
# 164 frames successfully loaded out of 1000
# 165 frames successfully loaded out of 1000
# 166 frames successfully loaded out of 1000
# 167 frames successfully loaded out of 1000
# 168 frames successfully loaded out of 1000
# 169 frames successfully loaded out of 1000
# 170 frames successfully loaded out of 1000
# 171 frames successfully loaded out of 1000
# 172 frames successfully loaded out of 1000
# 173 frames successfully loaded out of 1000
# 174 frames successfully loaded out of 1000
# 175 frames successfully loaded out of 1000
# 176 frames successfully loaded out of 1000
# 177 frames successfully loaded out of 1000
# 178 frames successfully loaded out of 1000
# 179 frames successfully loaded out of 1000
# 180 frames successfully loaded out of 1000
# 181 frames successfully loaded out of 1000
# 182 frames successfully loaded out of 1000
# 183 frames successfully loaded out of 1000
# 184 frames successfully loaded out of 1000
# 185 frames successfully loaded out of 1000
# 186 frames successfully loaded out of 1000
# 187 frames successfully loaded out of 1000
# 188 frames successfully loaded out of 1000
# 189 frames successfully loaded out of 1000
# 190 frames successfully loaded out of 1000
# 191 frames successfully loaded out of 1000
# 192 frames successfully loaded out of 1000
# 193 frames successfully loaded out of 1000
# 194 frames successfully loaded out of 1000
# 195 frames successfully loaded out of 1000
# 196 frames successfully loaded out of 1000
# 197 frames successfully loaded out of 1000
# 198 frames successfully loaded out of 1000
# 199 frames successfully loaded out of 1000
# 200 frames successfully loaded out of 1000
# 201 frames successfully loaded out of 1000
# 202 frames successfully loaded out of 1000
# 203 frames successfully loaded out of 1000
# 204 frames successfully loaded out of 1000
# 205 frames successfully loaded out of 1000
# 206 frames successfully loaded out of 1000
# 207 frames successfully loaded out of 1000
# 208 frames successfully loaded out of 1000
# 209 frames successfully loaded out of 1000
# 210 frames successfully loaded out of 1000
# 211 frames successfully loaded out of 1000
# 212 frames successfully loaded out of 1000
# 213 frames successfully loaded out of 1000
# 214 frames successfully loaded out of 1000
# 215 frames successfully loaded out of 1000
# 216 frames successfully loaded out of 1000
# 217 frames successfully loaded out of 1000
# 218 frames successfully loaded out of 1000
# 219 frames successfully loaded out of 1000
# 220 frames successfully loaded out of 1000
# 221 frames successfully loaded out of 1000
# 222 frames successfully loaded out of 1000
# 223 frames successfully loaded out of 1000
# 224 frames successfully loaded out of 1000
# 225 frames successfully loaded out of 1000
# 226 frames successfully loaded out of 1000
# 227 frames successfully loaded out of 1000
# 228 frames successfully loaded out of 1000
# 229 frames successfully loaded out of 1000
# 230 frames successfully loaded out of 1000
# 231 frames successfully loaded out of 1000
# 232 frames successfully loaded out of 1000
# 233 frames successfully loaded out of 1000
# 234 frames successfully loaded out of 1000
# 235 frames successfully loaded out of 1000
# 236 frames successfully loaded out of 1000
# 237 frames successfully loaded out of 1000
# 238 frames successfully loaded out of 1000
# 239 frames successfully loaded out of 1000
# 240 frames successfully loaded out of 1000
# 241 frames successfully loaded out of 1000
# 242 frames successfully loaded out of 1000
# 243 frames successfully loaded out of 1000
# 244 frames successfully loaded out of 1000
# 245 frames successfully loaded out of 1000
# 246 frames successfully loaded out of 1000
# 247 frames successfully loaded out of 1000
# 248 frames successfully loaded out of 1000
# 249 frames successfully loaded out of 1000
# 250 frames successfully loaded out of 1000
# 251 frames successfully loaded out of 1000
# 252 frames successfully loaded out of 1000
# 253 frames successfully loaded out of 1000
# 254 frames successfully loaded out of 1000
# 255 frames successfully loaded out of 1000
# 256 frames successfully loaded out of 1000
# 257 frames successfully loaded out of 1000
# 258 frames successfully loaded out of 1000
# 259 frames successfully loaded out of 1000
# 260 frames successfully loaded out of 1000
# 261 frames successfully loaded out of 1000
# 262 frames successfully loaded out of 1000
# 263 frames successfully loaded out of 1000
# 264 frames successfully loaded out of 1000
# 265 frames successfully loaded out of 1000
# 266 frames successfully loaded out of 1000
# 267 frames successfully loaded out of 1000
# 268 frames successfully loaded out of 1000
# 269 frames successfully loaded out of 1000
# 270 frames successfully loaded out of 1000
# 271 frames successfully loaded out of 1000
# 272 frames successfully loaded out of 1000
# 273 frames successfully loaded out of 1000
# 274 frames successfully loaded out of 1000
# 275 frames successfully loaded out of 1000
# 276 frames successfully loaded out of 1000
# 277 frames successfully loaded out of 1000
# 278 frames successfully loaded out of 1000
# 279 frames successfully loaded out of 1000
# 280 frames successfully loaded out of 1000
# 281 frames successfully loaded out of 1000
# 282 frames successfully loaded out of 1000
# 283 frames successfully loaded out of 1000
# 284 frames successfully loaded out of 1000
# 285 frames successfully loaded out of 1000
# 286 frames successfully loaded out of 1000
# 287 frames successfully loaded out of 1000
# 288 frames successfully loaded out of 1000
# 289 frames successfully loaded out of 1000
# 290 frames successfully loaded out of 1000
# 291 frames successfully loaded out of 1000
# 292 frames successfully loaded out of 1000
# 293 frames successfully loaded out of 1000
# 294 frames successfully loaded out of 1000
# 295 frames successfully loaded out of 1000
# 296 frames successfully loaded out of 1000
# 297 frames successfully loaded out of 1000
# 298 frames successfully loaded out of 1000
# 299 frames successfully loaded out of 1000
# 300 frames successfully loaded out of 1000
# 301 frames successfully loaded out of 1000
# 302 frames successfully loaded out of 1000
# 303 frames successfully loaded out of 1000
# 304 frames successfully loaded out of 1000
# 305 frames successfully loaded out of 1000
# 306 frames successfully loaded out of 1000
# 307 frames successfully loaded out of 1000
# 308 frames successfully loaded out of 1000
# 309 frames successfully loaded out of 1000
# 310 frames successfully loaded out of 1000
# 311 frames successfully loaded out of 1000
# 312 frames successfully loaded out of 1000
# 313 frames successfully loaded out of 1000
# 314 frames successfully loaded out of 1000
# 315 frames successfully loaded out of 1000
# 316 frames successfully loaded out of 1000
# 317 frames successfully loaded out of 1000
# 318 frames successfully loaded out of 1000
# 319 frames successfully loaded out of 1000
# 320 frames successfully loaded out of 1000
# 321 frames successfully loaded out of 1000
# 322 frames successfully loaded out of 1000
# 323 frames successfully loaded out of 1000
# 324 frames successfully loaded out of 1000
# 325 frames successfully loaded out of 1000
# 326 frames successfully loaded out of 1000
# 327 frames successfully loaded out of 1000
# 328 frames successfully loaded out of 1000
# 329 frames successfully loaded out of 1000
# 330 frames successfully loaded out of 1000
# 331 frames successfully loaded out of 1000
# 332 frames successfully loaded out of 1000
# 333 frames successfully loaded out of 1000
# 334 frames successfully loaded out of 1000
# 335 frames successfully loaded out of 1000
# 336 frames successfully loaded out of 1000
# 337 frames successfully loaded out of 1000
# 338 frames successfully loaded out of 1000
# 339 frames successfully loaded out of 1000
# 340 frames successfully loaded out of 1000
# 341 frames successfully loaded out of 1000
# 342 frames successfully loaded out of 1000
# 343 frames successfully loaded out of 1000
# 344 frames successfully loaded out of 1000
# 345 frames successfully loaded out of 1000
# 346 frames successfully loaded out of 1000
# 347 frames successfully loaded out of 1000
# 348 frames successfully loaded out of 1000
# 349 frames successfully loaded out of 1000
# 350 frames successfully loaded out of 1000
# 351 frames successfully loaded out of 1000
# 352 frames successfully loaded out of 1000
# 353 frames successfully loaded out of 1000
# 354 frames successfully loaded out of 1000
# 355 frames successfully loaded out of 1000
# 356 frames successfully loaded out of 1000
# 357 frames successfully loaded out of 1000
# 358 frames successfully loaded out of 1000
# 359 frames successfully loaded out of 1000
# 360 frames successfully loaded out of 1000
# 361 frames successfully loaded out of 1000
# 362 frames successfully loaded out of 1000
# 363 frames successfully loaded out of 1000
# 364 frames successfully loaded out of 1000
# 365 frames successfully loaded out of 1000
# 366 frames successfully loaded out of 1000
# 367 frames successfully loaded out of 1000
# 368 frames successfully loaded out of 1000
# 369 frames successfully loaded out of 1000
# 370 frames successfully loaded out of 1000
# 371 frames successfully loaded out of 1000
# 372 frames successfully loaded out of 1000
# 373 frames successfully loaded out of 1000
# 374 frames successfully loaded out of 1000
# 375 frames successfully loaded out of 1000
# 376 frames successfully loaded out of 1000
# 377 frames successfully loaded out of 1000
# 378 frames successfully loaded out of 1000
# 379 frames successfully loaded out of 1000
# 380 frames successfully loaded out of 1000
# 381 frames successfully loaded out of 1000
# 382 frames successfully loaded out of 1000
# 383 frames successfully loaded out of 1000
# 384 frames successfully loaded out of 1000
# 385 frames successfully loaded out of 1000
# 386 frames successfully loaded out of 1000
# 387 frames successfully loaded out of 1000
# 388 frames successfully loaded out of 1000
# 389 frames successfully loaded out of 1000
# 390 frames successfully loaded out of 1000
# 391 frames successfully loaded out of 1000
# 392 frames successfully loaded out of 1000
# 393 frames successfully loaded out of 1000
# 394 frames successfully loaded out of 1000
# 395 frames successfully loaded out of 1000
# 396 frames successfully loaded out of 1000
# 397 frames successfully loaded out of 1000
# 398 frames successfully loaded out of 1000
# 399 frames successfully loaded out of 1000
# 400 frames successfully loaded out of 1000
# 401 frames successfully loaded out of 1000
# 402 frames successfully loaded out of 1000
# 403 frames successfully loaded out of 1000
# 404 frames successfully loaded out of 1000
# 405 frames successfully loaded out of 1000
# 406 frames successfully loaded out of 1000
# 407 frames successfully loaded out of 1000
# 408 frames successfully loaded out of 1000
# 409 frames successfully loaded out of 1000
# 410 frames successfully loaded out of 1000
# 411 frames successfully loaded out of 1000
# 412 frames successfully loaded out of 1000
# 413 frames successfully loaded out of 1000
# 414 frames successfully loaded out of 1000
# 415 frames successfully loaded out of 1000
# 416 frames successfully loaded out of 1000
# 417 frames successfully loaded out of 1000
# 418 frames successfully loaded out of 1000
# 419 frames successfully loaded out of 1000
# 420 frames successfully loaded out of 1000
# 421 frames successfully loaded out of 1000
# 422 frames successfully loaded out of 1000
# 423 frames successfully loaded out of 1000
# 424 frames successfully loaded out of 1000
# 425 frames successfully loaded out of 1000
# 426 frames successfully loaded out of 1000
# 427 frames successfully loaded out of 1000
# 428 frames successfully loaded out of 1000
# 429 frames successfully loaded out of 1000
# 430 frames successfully loaded out of 1000
# 431 frames successfully loaded out of 1000
# 432 frames successfully loaded out of 1000
# 433 frames successfully loaded out of 1000
# 434 frames successfully loaded out of 1000
# 435 frames successfully loaded out of 1000
# 436 frames successfully loaded out of 1000
# 437 frames successfully loaded out of 1000
# 438 frames successfully loaded out of 1000
# 439 frames successfully loaded out of 1000
# 440 frames successfully loaded out of 1000
# 441 frames successfully loaded out of 1000
# 442 frames successfully loaded out of 1000
# 443 frames successfully loaded out of 1000
# 444 frames successfully loaded out of 1000
# 445 frames successfully loaded out of 1000
# 446 frames successfully loaded out of 1000
# 447 frames successfully loaded out of 1000
# 448 frames successfully loaded out of 1000
# 449 frames successfully loaded out of 1000
# 450 frames successfully loaded out of 1000
# 451 frames successfully loaded out of 1000
# 452 frames successfully loaded out of 1000
# 453 frames successfully loaded out of 1000
# 454 frames successfully loaded out of 1000
# 455 frames successfully loaded out of 1000
# 456 frames successfully loaded out of 1000
# 457 frames successfully loaded out of 1000
# 458 frames successfully loaded out of 1000
# 459 frames successfully loaded out of 1000
# 460 frames successfully loaded out of 1000
# 461 frames successfully loaded out of 1000
# 462 frames successfully loaded out of 1000
# 463 frames successfully loaded out of 1000
# 464 frames successfully loaded out of 1000
# 465 frames successfully loaded out of 1000
# 466 frames successfully loaded out of 1000
# 467 frames successfully loaded out of 1000
# 468 frames successfully loaded out of 1000
# 469 frames successfully loaded out of 1000
# 470 frames successfully loaded out of 1000
# 471 frames successfully loaded out of 1000
# 472 frames successfully loaded out of 1000
# 473 frames successfully loaded out of 1000
# 474 frames successfully loaded out of 1000
# 475 frames successfully loaded out of 1000
# 476 frames successfully loaded out of 1000
# 477 frames successfully loaded out of 1000
# 478 frames successfully loaded out of 1000
# 479 frames successfully loaded out of 1000
# 480 frames successfully loaded out of 1000
# 481 frames successfully loaded out of 1000
# 482 frames successfully loaded out of 1000
# 483 frames successfully loaded out of 1000
# 484 frames successfully loaded out of 1000
# 485 frames successfully loaded out of 1000
# 486 frames successfully loaded out of 1000
# 487 frames successfully loaded out of 1000
# 488 frames successfully loaded out of 1000
# 489 frames successfully loaded out of 1000
# 490 frames successfully loaded out of 1000
# 491 frames successfully loaded out of 1000
# 492 frames successfully loaded out of 1000
# 493 frames successfully loaded out of 1000
# 494 frames successfully loaded out of 1000
# 495 frames successfully loaded out of 1000
# 496 frames successfully loaded out of 1000
# 497 frames successfully loaded out of 1000
# 498 frames successfully loaded out of 1000
# 499 frames successfully loaded out of 1000
# 500 frames successfully loaded out of 1000
# 501 frames successfully loaded out of 1000
# 502 frames successfully loaded out of 1000
# 503 frames successfully loaded out of 1000
# 504 frames successfully loaded out of 1000
# 505 frames successfully loaded out of 1000
# 506 frames successfully loaded out of 1000
# 507 frames successfully loaded out of 1000
# 508 frames successfully loaded out of 1000
# 509 frames successfully loaded out of 1000
# 510 frames successfully loaded out of 1000
# 511 frames successfully loaded out of 1000
# 512 frames successfully loaded out of 1000
# 513 frames successfully loaded out of 1000
# 514 frames successfully loaded out of 1000
# 515 frames successfully loaded out of 1000
# 516 frames successfully loaded out of 1000
# 517 frames successfully loaded out of 1000
# 518 frames successfully loaded out of 1000
# 519 frames successfully loaded out of 1000
# 520 frames successfully loaded out of 1000
# 521 frames successfully loaded out of 1000
# 522 frames successfully loaded out of 1000
# 523 frames successfully loaded out of 1000
# 524 frames successfully loaded out of 1000
# 525 frames successfully loaded out of 1000
# 526 frames successfully loaded out of 1000
# 527 frames successfully loaded out of 1000
# 528 frames successfully loaded out of 1000
# 529 frames successfully loaded out of 1000
# 530 frames successfully loaded out of 1000
# 531 frames successfully loaded out of 1000
# 532 frames successfully loaded out of 1000
# 533 frames successfully loaded out of 1000
# 534 frames successfully loaded out of 1000
# 535 frames successfully loaded out of 1000
# 536 frames successfully loaded out of 1000
# 537 frames successfully loaded out of 1000
# 538 frames successfully loaded out of 1000
# 539 frames successfully loaded out of 1000
# 540 frames successfully loaded out of 1000
# 541 frames successfully loaded out of 1000
# 542 frames successfully loaded out of 1000
# 543 frames successfully loaded out of 1000
# 544 frames successfully loaded out of 1000
# 545 frames successfully loaded out of 1000
# 546 frames successfully loaded out of 1000
# 547 frames successfully loaded out of 1000
# 548 frames successfully loaded out of 1000
# 549 frames successfully loaded out of 1000
# 550 frames successfully loaded out of 1000
# 551 frames successfully loaded out of 1000
# 552 frames successfully loaded out of 1000
# 553 frames successfully loaded out of 1000
# 554 frames successfully loaded out of 1000
# 555 frames successfully loaded out of 1000
# 556 frames successfully loaded out of 1000
# 557 frames successfully loaded out of 1000
# 558 frames successfully loaded out of 1000
# 559 frames successfully loaded out of 1000
# 560 frames successfully loaded out of 1000
# 561 frames successfully loaded out of 1000
# 562 frames successfully loaded out of 1000
# 563 frames successfully loaded out of 1000
# 564 frames successfully loaded out of 1000
# 565 frames successfully loaded out of 1000
# 566 frames successfully loaded out of 1000
# 567 frames successfully loaded out of 1000
# 568 frames successfully loaded out of 1000
# 569 frames successfully loaded out of 1000
# 570 frames successfully loaded out of 1000
# 571 frames successfully loaded out of 1000
# 572 frames successfully loaded out of 1000
# 573 frames successfully loaded out of 1000
# 574 frames successfully loaded out of 1000
# 575 frames successfully loaded out of 1000
# 576 frames successfully loaded out of 1000
# 577 frames successfully loaded out of 1000
# 578 frames successfully loaded out of 1000
# 579 frames successfully loaded out of 1000
# 580 frames successfully loaded out of 1000
# 581 frames successfully loaded out of 1000
# 582 frames successfully loaded out of 1000
# 583 frames successfully loaded out of 1000
# 584 frames successfully loaded out of 1000
# 585 frames successfully loaded out of 1000
# 586 frames successfully loaded out of 1000
# 587 frames successfully loaded out of 1000
# 588 frames successfully loaded out of 1000
# 589 frames successfully loaded out of 1000
# 590 frames successfully loaded out of 1000
# 591 frames successfully loaded out of 1000
# 592 frames successfully loaded out of 1000
# 593 frames successfully loaded out of 1000
# 594 frames successfully loaded out of 1000
# 595 frames successfully loaded out of 1000
# 596 frames successfully loaded out of 1000
# 597 frames successfully loaded out of 1000
# 598 frames successfully loaded out of 1000
# 599 frames successfully loaded out of 1000
# 600 frames successfully loaded out of 1000
# 601 frames successfully loaded out of 1000
# 602 frames successfully loaded out of 1000
# 603 frames successfully loaded out of 1000
# 604 frames successfully loaded out of 1000
# 605 frames successfully loaded out of 1000
# 606 frames successfully loaded out of 1000
# 607 frames successfully loaded out of 1000
# 608 frames successfully loaded out of 1000
# 609 frames successfully loaded out of 1000
# 610 frames successfully loaded out of 1000
# 611 frames successfully loaded out of 1000
# 612 frames successfully loaded out of 1000
# 613 frames successfully loaded out of 1000
# 614 frames successfully loaded out of 1000
# 615 frames successfully loaded out of 1000
# 616 frames successfully loaded out of 1000
# 617 frames successfully loaded out of 1000
# 618 frames successfully loaded out of 1000
# 619 frames successfully loaded out of 1000
# 620 frames successfully loaded out of 1000
# 621 frames successfully loaded out of 1000
# 622 frames successfully loaded out of 1000
# 623 frames successfully loaded out of 1000
# 624 frames successfully loaded out of 1000
# 625 frames successfully loaded out of 1000
# 626 frames successfully loaded out of 1000
# 627 frames successfully loaded out of 1000
# 628 frames successfully loaded out of 1000
# 629 frames successfully loaded out of 1000
# 630 frames successfully loaded out of 1000
# 631 frames successfully loaded out of 1000
# 632 frames successfully loaded out of 1000
# 633 frames successfully loaded out of 1000
# 634 frames successfully loaded out of 1000
# 635 frames successfully loaded out of 1000
# 636 frames successfully loaded out of 1000
# 637 frames successfully loaded out of 1000
# 638 frames successfully loaded out of 1000
# 639 frames successfully loaded out of 1000
# 640 frames successfully loaded out of 1000
# 641 frames successfully loaded out of 1000
# 642 frames successfully loaded out of 1000
# 643 frames successfully loaded out of 1000
# 644 frames successfully loaded out of 1000
# 645 frames successfully loaded out of 1000
# 646 frames successfully loaded out of 1000
# 647 frames successfully loaded out of 1000
# 648 frames successfully loaded out of 1000
# 649 frames successfully loaded out of 1000
# 650 frames successfully loaded out of 1000
# 651 frames successfully loaded out of 1000
# 652 frames successfully loaded out of 1000
# 653 frames successfully loaded out of 1000
# 654 frames successfully loaded out of 1000
# 655 frames successfully loaded out of 1000
# 656 frames successfully loaded out of 1000
# 657 frames successfully loaded out of 1000
# 658 frames successfully loaded out of 1000
# 659 frames successfully loaded out of 1000
# 660 frames successfully loaded out of 1000
# 661 frames successfully loaded out of 1000
# 662 frames successfully loaded out of 1000
# 663 frames successfully loaded out of 1000
# 664 frames successfully loaded out of 1000
# 665 frames successfully loaded out of 1000
# 666 frames successfully loaded out of 1000
# 667 frames successfully loaded out of 1000
# 668 frames successfully loaded out of 1000
# 669 frames successfully loaded out of 1000
# 670 frames successfully loaded out of 1000
# 671 frames successfully loaded out of 1000
# 672 frames successfully loaded out of 1000
# 673 frames successfully loaded out of 1000
# 674 frames successfully loaded out of 1000
# 675 frames successfully loaded out of 1000
# 676 frames successfully loaded out of 1000
# 677 frames successfully loaded out of 1000
# 678 frames successfully loaded out of 1000
# 679 frames successfully loaded out of 1000
# 680 frames successfully loaded out of 1000
# 681 frames successfully loaded out of 1000
# 682 frames successfully loaded out of 1000
# 683 frames successfully loaded out of 1000
# 684 frames successfully loaded out of 1000
# 685 frames successfully loaded out of 1000
# 686 frames successfully loaded out of 1000
# 687 frames successfully loaded out of 1000
# 688 frames successfully loaded out of 1000
# 689 frames successfully loaded out of 1000
# 690 frames successfully loaded out of 1000
# 691 frames successfully loaded out of 1000
# 692 frames successfully loaded out of 1000
# 693 frames successfully loaded out of 1000
# 694 frames successfully loaded out of 1000
# 695 frames successfully loaded out of 1000
# 696 frames successfully loaded out of 1000
# 697 frames successfully loaded out of 1000
# 698 frames successfully loaded out of 1000
# 699 frames successfully loaded out of 1000
# 700 frames successfully loaded out of 1000
# 701 frames successfully loaded out of 1000
# 702 frames successfully loaded out of 1000
# 703 frames successfully loaded out of 1000
# 704 frames successfully loaded out of 1000
# 705 frames successfully loaded out of 1000
# 706 frames successfully loaded out of 1000
# 707 frames successfully loaded out of 1000
# 708 frames successfully loaded out of 1000
# 709 frames successfully loaded out of 1000
# 710 frames successfully loaded out of 1000
# 711 frames successfully loaded out of 1000
# 712 frames successfully loaded out of 1000
# 713 frames successfully loaded out of 1000
# 714 frames successfully loaded out of 1000
# 715 frames successfully loaded out of 1000
# 716 frames successfully loaded out of 1000
# 717 frames successfully loaded out of 1000
# 718 frames successfully loaded out of 1000
# 719 frames successfully loaded out of 1000
# 720 frames successfully loaded out of 1000
# 721 frames successfully loaded out of 1000
# 722 frames successfully loaded out of 1000
# 723 frames successfully loaded out of 1000
# 724 frames successfully loaded out of 1000
# 725 frames successfully loaded out of 1000
# 726 frames successfully loaded out of 1000
# 727 frames successfully loaded out of 1000
# 728 frames successfully loaded out of 1000
# 729 frames successfully loaded out of 1000
# 730 frames successfully loaded out of 1000
# 731 frames successfully loaded out of 1000
# 732 frames successfully loaded out of 1000
# 733 frames successfully loaded out of 1000
# 734 frames successfully loaded out of 1000
# 735 frames successfully loaded out of 1000
# 736 frames successfully loaded out of 1000
# 737 frames successfully loaded out of 1000
# 738 frames successfully loaded out of 1000
# 739 frames successfully loaded out of 1000
# 740 frames successfully loaded out of 1000
# 741 frames successfully loaded out of 1000
# 742 frames successfully loaded out of 1000
# 743 frames successfully loaded out of 1000
# 744 frames successfully loaded out of 1000
# 745 frames successfully loaded out of 1000
# 746 frames successfully loaded out of 1000
# 747 frames successfully loaded out of 1000
# 748 frames successfully loaded out of 1000
# 749 frames successfully loaded out of 1000
# 750 frames successfully loaded out of 1000
# 751 frames successfully loaded out of 1000
# 752 frames successfully loaded out of 1000
# 753 frames successfully loaded out of 1000
# 754 frames successfully loaded out of 1000
# 755 frames successfully loaded out of 1000
# 756 frames successfully loaded out of 1000
# 757 frames successfully loaded out of 1000
# 758 frames successfully loaded out of 1000
# 759 frames successfully loaded out of 1000
# 760 frames successfully loaded out of 1000
# 761 frames successfully loaded out of 1000
# 762 frames successfully loaded out of 1000
# 763 frames successfully loaded out of 1000
# 764 frames successfully loaded out of 1000
# 765 frames successfully loaded out of 1000
# 766 frames successfully loaded out of 1000
# 767 frames successfully loaded out of 1000
# 768 frames successfully loaded out of 1000
# 769 frames successfully loaded out of 1000
# 770 frames successfully loaded out of 1000
# 771 frames successfully loaded out of 1000
# 772 frames successfully loaded out of 1000
# 773 frames successfully loaded out of 1000
# 774 frames successfully loaded out of 1000
# 775 frames successfully loaded out of 1000
# 776 frames successfully loaded out of 1000
# 777 frames successfully loaded out of 1000
# 778 frames successfully loaded out of 1000
# 779 frames successfully loaded out of 1000
# 780 frames successfully loaded out of 1000
# 781 frames successfully loaded out of 1000
# 782 frames successfully loaded out of 1000
# 783 frames successfully loaded out of 1000
# 784 frames successfully loaded out of 1000
# 785 frames successfully loaded out of 1000
# 786 frames successfully loaded out of 1000
# 787 frames successfully loaded out of 1000
# 788 frames successfully loaded out of 1000
# 789 frames successfully loaded out of 1000
# 790 frames successfully loaded out of 1000
# 791 frames successfully loaded out of 1000
# 792 frames successfully loaded out of 1000
# 793 frames successfully loaded out of 1000
# 794 frames successfully loaded out of 1000
# 795 frames successfully loaded out of 1000
# 796 frames successfully loaded out of 1000
# 797 frames successfully loaded out of 1000
# 798 frames successfully loaded out of 1000
# 799 frames successfully loaded out of 1000
# 800 frames successfully loaded out of 1000
# 801 frames successfully loaded out of 1000
# 802 frames successfully loaded out of 1000
# 803 frames successfully loaded out of 1000
# 804 frames successfully loaded out of 1000
# 805 frames successfully loaded out of 1000
# 806 frames successfully loaded out of 1000
# 807 frames successfully loaded out of 1000
# 808 frames successfully loaded out of 1000
# 809 frames successfully loaded out of 1000
# 810 frames successfully loaded out of 1000
# 811 frames successfully loaded out of 1000
# 812 frames successfully loaded out of 1000
# 813 frames successfully loaded out of 1000
# 814 frames successfully loaded out of 1000
# 815 frames successfully loaded out of 1000
# 816 frames successfully loaded out of 1000
# 817 frames successfully loaded out of 1000
# 818 frames successfully loaded out of 1000
# 819 frames successfully loaded out of 1000
# 820 frames successfully loaded out of 1000
# 821 frames successfully loaded out of 1000
# 822 frames successfully loaded out of 1000
# 823 frames successfully loaded out of 1000
# 824 frames successfully loaded out of 1000
# 825 frames successfully loaded out of 1000
# 826 frames successfully loaded out of 1000
# 827 frames successfully loaded out of 1000
# 828 frames successfully loaded out of 1000
# 829 frames successfully loaded out of 1000
# 830 frames successfully loaded out of 1000
# 831 frames successfully loaded out of 1000
# 832 frames successfully loaded out of 1000
# 833 frames successfully loaded out of 1000
# 834 frames successfully loaded out of 1000
# 835 frames successfully loaded out of 1000
# 836 frames successfully loaded out of 1000
# 837 frames successfully loaded out of 1000
# 838 frames successfully loaded out of 1000
# 839 frames successfully loaded out of 1000
# 840 frames successfully loaded out of 1000
# 841 frames successfully loaded out of 1000
# 842 frames successfully loaded out of 1000
# 843 frames successfully loaded out of 1000
# 844 frames successfully loaded out of 1000
# 845 frames successfully loaded out of 1000
# 846 frames successfully loaded out of 1000
# 847 frames successfully loaded out of 1000
# 848 frames successfully loaded out of 1000
# 849 frames successfully loaded out of 1000
# 850 frames successfully loaded out of 1000
# 851 frames successfully loaded out of 1000
# 852 frames successfully loaded out of 1000
# 853 frames successfully loaded out of 1000
# 854 frames successfully loaded out of 1000
# 855 frames successfully loaded out of 1000
# 856 frames successfully loaded out of 1000
# 857 frames successfully loaded out of 1000
# 858 frames successfully loaded out of 1000
# 859 frames successfully loaded out of 1000
# 860 frames successfully loaded out of 1000
# 861 frames successfully loaded out of 1000
# 862 frames successfully loaded out of 1000
# 863 frames successfully loaded out of 1000
# 864 frames successfully loaded out of 1000
# 865 frames successfully loaded out of 1000
# 866 frames successfully loaded out of 1000
# 867 frames successfully loaded out of 1000
# 868 frames successfully loaded out of 1000
# 869 frames successfully loaded out of 1000
# 870 frames successfully loaded out of 1000
# 871 frames successfully loaded out of 1000
# 872 frames successfully loaded out of 1000
# 873 frames successfully loaded out of 1000
# 874 frames successfully loaded out of 1000
# 875 frames successfully loaded out of 1000
# 876 frames successfully loaded out of 1000
# 877 frames successfully loaded out of 1000
# 878 frames successfully loaded out of 1000
# 879 frames successfully loaded out of 1000
# 880 frames successfully loaded out of 1000
# 881 frames successfully loaded out of 1000
# 882 frames successfully loaded out of 1000
# 883 frames successfully loaded out of 1000
# 884 frames successfully loaded out of 1000
# 885 frames successfully loaded out of 1000
# 886 frames successfully loaded out of 1000
# 887 frames successfully loaded out of 1000
# 888 frames successfully loaded out of 1000
# 889 frames successfully loaded out of 1000
# 890 frames successfully loaded out of 1000
# 891 frames successfully loaded out of 1000
# 892 frames successfully loaded out of 1000
# 893 frames successfully loaded out of 1000
# 894 frames successfully loaded out of 1000
# 895 frames successfully loaded out of 1000
# 896 frames successfully loaded out of 1000
# 897 frames successfully loaded out of 1000
# 898 frames successfully loaded out of 1000
# 899 frames successfully loaded out of 1000
# 900 frames successfully loaded out of 1000
# 901 frames successfully loaded out of 1000
# 902 frames successfully loaded out of 1000
# 903 frames successfully loaded out of 1000
# 904 frames successfully loaded out of 1000
# 905 frames successfully loaded out of 1000
# 906 frames successfully loaded out of 1000
# 907 frames successfully loaded out of 1000
# 908 frames successfully loaded out of 1000
# 909 frames successfully loaded out of 1000
# 910 frames successfully loaded out of 1000
# 911 frames successfully loaded out of 1000
# 912 frames successfully loaded out of 1000
# 913 frames successfully loaded out of 1000
# 914 frames successfully loaded out of 1000
# 915 frames successfully loaded out of 1000
# 916 frames successfully loaded out of 1000
# 917 frames successfully loaded out of 1000
# 918 frames successfully loaded out of 1000
# 919 frames successfully loaded out of 1000
# 920 frames successfully loaded out of 1000
# 921 frames successfully loaded out of 1000
# 922 frames successfully loaded out of 1000
# 923 frames successfully loaded out of 1000
# 924 frames successfully loaded out of 1000
# 925 frames successfully loaded out of 1000
# 926 frames successfully loaded out of 1000
# 927 frames successfully loaded out of 1000
# 928 frames successfully loaded out of 1000
# 929 frames successfully loaded out of 1000
# 930 frames successfully loaded out of 1000
# 931 frames successfully loaded out of 1000
# 932 frames successfully loaded out of 1000
# 933 frames successfully loaded out of 1000
# 934 frames successfully loaded out of 1000
# 935 frames successfully loaded out of 1000
# 936 frames successfully loaded out of 1000
# 937 frames successfully loaded out of 1000
# 938 frames successfully loaded out of 1000
# 939 frames successfully loaded out of 1000
# 940 frames successfully loaded out of 1000
# 941 frames successfully loaded out of 1000
# 942 frames successfully loaded out of 1000
# 943 frames successfully loaded out of 1000
# 944 frames successfully loaded out of 1000
# 945 frames successfully loaded out of 1000
# 946 frames successfully loaded out of 1000
# 947 frames successfully loaded out of 1000
# 948 frames successfully loaded out of 1000
# 949 frames successfully loaded out of 1000
# 950 frames successfully loaded out of 1000
# 951 frames successfully loaded out of 1000
# 952 frames successfully loaded out of 1000
# 953 frames successfully loaded out of 1000
# 954 frames successfully loaded out of 1000
# 955 frames successfully loaded out of 1000
# 956 frames successfully loaded out of 1000
# 957 frames successfully loaded out of 1000
# 958 frames successfully loaded out of 1000
# 959 frames successfully loaded out of 1000
# 960 frames successfully loaded out of 1000
# 961 frames successfully loaded out of 1000
# 962 frames successfully loaded out of 1000
# 963 frames successfully loaded out of 1000
# 964 frames successfully loaded out of 1000
# 965 frames successfully loaded out of 1000
# 966 frames successfully loaded out of 1000
# 967 frames successfully loaded out of 1000
# 968 frames successfully loaded out of 1000
# 969 frames successfully loaded out of 1000
# 970 frames successfully loaded out of 1000
# 971 frames successfully loaded out of 1000
# 972 frames successfully loaded out of 1000
# 973 frames successfully loaded out of 1000
# 974 frames successfully loaded out of 1000
# 975 frames successfully loaded out of 1000
# 976 frames successfully loaded out of 1000
# 977 frames successfully loaded out of 1000
# 978 frames successfully loaded out of 1000
# 979 frames successfully loaded out of 1000
# 980 frames successfully loaded out of 1000
# 981 frames successfully loaded out of 1000
# 982 frames successfully loaded out of 1000
# 983 frames successfully loaded out of 1000
# 984 frames successfully loaded out of 1000
# 985 frames successfully loaded out of 1000
# 986 frames successfully loaded out of 1000
# 987 frames successfully loaded out of 1000
# 988 frames successfully loaded out of 1000
# 989 frames successfully loaded out of 1000
# 990 frames successfully loaded out of 1000
# 991 frames successfully loaded out of 1000
# 992 frames successfully loaded out of 1000
# 993 frames successfully loaded out of 1000
# 994 frames successfully loaded out of 1000
# 995 frames successfully loaded out of 1000
# 996 frames successfully loaded out of 1000
# 997 frames successfully loaded out of 1000
# 998 frames successfully loaded out of 1000
# 999 frames successfully loaded out of 1000
# 1000 frames successfully loaded out of 1000
#
# Car count: 502
# Truck count: 498
# 4 more cars than trucks.

# %% [markdown]
# # Reef Steps
# Reef generates heuristics in an iterative manner, with each iteration consisting of the following steps:
# 1. Synthesize Heuristics
# 2. Prune Heuristics
# 3. Verify Heuristics
#
# In this tutorial, we go through the three stages of Reef individually and then repeat the process iteratively.

# %% [markdown]
# In the cell below, we run a single iteration by calling the `run_synthesizer` function. We pass in the primitive matrices for the `train` and `val` sets, along with ground truth labels for `val`. While we also pass in ground truth labels for `train`, this is solely for evaluation purposes.
#
# `max_cardinality` is the maximum number of primitives a heuristic takes as input, `keep` is how many heuristics the pruner should select (3 for the first iteration, 1 after that) and `model` is the type of heuristic to generate, in this case, `decision_tree`.
#
# _This cell does not output anything, only saves values in HeuristicGenerator._

# %%
from program_synthesis.heuristic_generator import HeuristicGenerator
hg = HeuristicGenerator(train_primitive_matrix, val_primitive_matrix, val_ground, train_ground, b=0.5)
hg.run_synthesizer(max_cardinality=1, idx=None, keep=3, model='dt')

# %% [markdown]
# ## 1. Synthesize Heuristics
# We start by generating all possible heuristics based on the labeled, validation set that take in a single feature (i.e. word for this example) as input.
#
# For this example, we use decision trees with maximum depth 1 (`dt`) as our heuristic form. We first generate all possible heuristics that take a single feature in as input.

# %%
from program_synthesis.synthesizer import Synthesizer
syn = Synthesizer(val_primitive_matrix, val_ground, b=0.5)

heuristics, feature_inputs = syn.generate_heuristics('nn', 1)
print("Total Heuristics Generated: ", np.shape(heuristics)[1])
# Out:
# Total Heuristics Generated:  512

# %% [markdown]
# For each generated heuristic, we find an associated $\beta$ value.  This corresponds to defining a region of **low confidence** labels, which the heuristic will abstain for, while labeling the rest of the datapoints as $1$ or $-1$.

# %%
optimal_betas = syn.find_optimal_beta(heuristics[0], val_primitive_matrix, feature_inputs[0], val_ground)
plt.hist(optimal_betas, range=(0,0.5));
plt.xlabel('Beta Values');

# %% [markdown]
# ## 2. Prune Heuristics
# In the first iteration, we simply pick the 3 heuristics that perform the best on the labeled validation set.

# %%
top_idx = hg.prune_heuristics(heuristics, feature_inputs, keep=3)
print('Features chosen heuristics are based on: ', top_idx)
# Out:
# Features chosen heuristics are based on:  [222 242 183]

# %% [markdown]
# In subsequent iterations (step 4), we weight the Jaccard score (overlap of how many datapoints in the train set receive labels and how many are labeled by existing heuristics) and F1 score equally. We demonstrate this with a toy vector of previously labeled data.

# %% [markdown]
# ## 3. Verify Heuristics
# In this step, we use the labels the heuristics assign to the **unlabeled train set** to estimate heuristic accuracies and assign probabilistic training labels to the same set accordingly (see [snorkel.stanford.edu](http://snorkel.stanford.edu) for more details).

# %%
from program_synthesis.verifier import Verifier
verifier = Verifier(hg.L_train, hg.L_val, val_ground, has_snorkel=False)

verifier.train_gen_model()
verifier.assign_marginals()

# %% [markdown]
# We visualize what these labels look like. Note that with a single iteration, none of the datapoints receive a probabilistic label greater than 0.5, but this is fixed after running the process iteratively (Step 4). __These labels are then used to train an end model, such as an LSTM, and not used as final predictions.__

# %%
plt.hist(verifier.train_marginals); plt.title('Training Set Probabilistic Labels');

# %% [markdown]
# Since we do not have access to ground truth labels for the train set, we use the distribution of labels for the labeled validation set to decide what feedback to pass to the synthesizer. We pass datapoints with low confidence (labels near 0.5, i.e. equal probability of being +1 or -1) to the synthesizer

# %%
plt.hist(verifier.val_marginals); plt.title('Validation Set Probabilistic Labels');
feedback_idx = verifier.find_vague_points(gamma=0.1,b=0.5)
print('Percentage of Low Confidence Points: ', np.shape(feedback_idx)[0]/float(np.shape(val_ground)[0]))
# Out:
# Percentage of Low Confidence Points:  0.49375

# %% [markdown]
# ## 4. Repeat Iterative Process of Generating Heuristics
# We repeat this process of synthesizing, pruning, and verifying heuristics iteratively. In this example, we generate 25 total heuristics.
#
# _Note that this process wil take a few minutes to run since heuristic generation is not currently optimized in any manner_

# %%
validation_accuracy = []
training_accuracy = []
validation_coverage = []
training_coverage = []

training_marginals = []
idx = None

hg = HeuristicGenerator(train_primitive_matrix, val_primitive_matrix, 
                            val_ground, train_ground, 
                            b=0.5)
plt.figure(figsize=(12,6));
for i in range(3,26):
    if (i-2)%5 == 0:
        print("Running iteration: ", str(i-2))
        
    #Repeat synthesize-prune-verify at each iterations
    if i == 3:
        hg.run_synthesizer(max_cardinality=1, idx=idx, keep=3, model='nn')
    else:
        hg.run_synthesizer(max_cardinality=1, idx=idx, keep=1, model='nn')
    hg.run_verifier()
    
    #Save evaluation metrics
    va,ta, vc, tc = hg.evaluate()
    validation_accuracy.append(va)
    training_accuracy.append(ta)
    training_marginals.append(hg.vf.train_marginals)
    validation_coverage.append(vc)
    training_coverage.append(tc)
    
    #Plot Training Set Label Distribution
    if i <= 8:
        plt.subplot(2,3,i-2)
        plt.hist(training_marginals[-1], bins=10, range=(0.0,1.0)); 
        plt.title('Iteration ' + str(i-2));
        plt.xlim([0.0,1.0])
        # plt.ylim([0,825])
    
    #Find low confidence datapoints in the labeled set
    hg.find_feedback()
    idx = hg.feedback_idx
    
    #Stop the iterative process when no low confidence labels
    if idx == []:
        break
plt.tight_layout()
# Out:
# Running iteration:  5
# Running iteration:  10
# Running iteration:  15
# Running iteration:  20

# %% [markdown]
# In the plots above, we show the distribution of probabilistic labels Reef assigns to the training set in the first few iterations.
#
# Next, we look at the accuracy and coverage of labels assigned to the training set in the _last_ iteration. The coverage is the percentage of training set datapoints that receive at least one label from the generated heuristics.

# %%
plt.hist(training_marginals[-1], bins=10, range=(0.0,1.0)); 
plt.title('Final Distribution');

print("Program Synthesis Train Accuracy: ", training_accuracy[-1])
print("Program Synthesis Train Coverage: ", training_coverage[-1])
print("Program Synthesis Validation Accuracy: ", validation_accuracy[-1])

print(training_accuracy)
print(validation_accuracy)
